# %% [markdown]
# ### Day 7
# #### part A

# %%
import re
import numpy as np

# %%
infile="07a_input.txt"

# %%
with open(infile) as f:
    lines=f.readlines()

# %%
lines=[line.replace("\n","") for line in lines]
lines[:5]
# Out:
# ['drab tan bags contain 4 clear gold bags.',
#  'vibrant lime bags contain 3 faded gold bags, 3 plaid aqua bags, 2 clear black bags.',
#  'pale lime bags contain 1 dim salmon bag, 5 faded salmon bags, 1 dim turquoise bag.',
#  'dull gray bags contain 1 striped gold bag, 1 vibrant yellow bag.',
#  'light fuchsia bags contain 4 light lavender bags, 5 faded olive bags, 4 plaid cyan bags, 1 striped tomato bag.']

# %% [markdown]
# split each line into "outer color" bag, a list of allowed "inner color" bags and their "counts"

# %%
colors_outer=[]
colors_inner=[]
counts_inner=[]

for line in lines:
    outer, inner=line.split("contain")
    
    # outer
    curcol_outer, _ =outer.split(" bags",maxsplit=1)
    colors_outer.append(curcol_outer)
    
    # inner
    pattern=r"(?P<count>\d) (?P<color>\w+ \w+) bags?" # example hit: 1 shiny brown bag

    iterable=re.finditer(pattern, inner)
    curcol_inner=[]
    curcount_inner=[]
    for match in iterable:
        curcount_inner.append(int(match.group("count"))) # ex: 1
        curcol_inner.append(match.group("color")) # ex: shiny brown
    
    counts_inner.append(curcount_inner)
    colors_inner.append(curcol_inner)

# %%
# show how the data structure looks now
display(lines[:3])
print("outer:",colors_outer[:3])
print("inner count:",counts_inner[:3])
print("inner color:",colors_inner[:3])
# Out:
# ['drab tan bags contain 4 clear gold bags.',
#  'vibrant lime bags contain 3 faded gold bags, 3 plaid aqua bags, 2 clear black bags.',
#  'pale lime bags contain 1 dim salmon bag, 5 faded salmon bags, 1 dim turquoise bag.']
# outer: ['drab tan', 'vibrant lime', 'pale lime']
# inner count: [[4], [3, 3, 2], [1, 5, 1]]
# inner color: [['clear gold'], ['faded gold', 'plaid aqua', 'clear black'], ['dim salmon', 'faded salmon', 'dim turquoise']]

# %% [markdown]
# convert colors to numbers (indexing)

# %%
converter=dict(zip(colors_outer,range(len(colors_outer))))
converter
# Out:
# {'drab tan': 0,
#  'vibrant lime': 1,
#  'pale lime': 2,
#  'dull gray': 3,
#  'light fuchsia': 4,
#  'drab gold': 5,
#  'dim red': 6,
#  'striped orange': 7,
#  'shiny violet': 8,
#  'faded olive': 9,
#  'dotted lime': 10,
#  'drab magenta': 11,
#  'dull black': 12,
#  'posh turquoise': 13,
#  'muted purple': 14,
#  'striped black': 15,
#  'drab brown': 16,
#  'pale purple': 17,
#  'dark turquoise': 18,
#  'clear lavender': 19,
#  'bright coral': 20,
#  'posh coral': 21,
#  'drab lime': 22,
#  'striped brown': 23,
#  'wavy bronze': 24,
#  'dim black': 25,
#  'posh yellow': 26,
#  'pale violet': 27,
#  'mirrored bronze': 28,
#  'vibrant silver': 29,
#  'dark brown': 30,
#  'wavy green': 31,
#  'light beige': 32,
#  'wavy crimson': 33,
#  'clear tan': 34,
#  'posh lime': 35,
#  'pale blue': 36,
#  'wavy silver': 37,
#  'striped beige': 38,
#  'dim gold': 39,
#  'vibrant teal': 40,
#  'light tan': 41,
#  'dark red': 42,
#  'posh salmon': 43,
#  'mirrored yellow': 44,
#  'dark fuchsia': 45,
#  'bright bronze': 46,
#  'posh silver': 47,
#  'dotted salmon': 48,
#  'dark orange': 49,
#  'bright silver': 50,
#  'posh orange': 51,
#  'mirrored olive': 52,
#  'drab beige': 53,
#  'muted bronze': 54,
#  'dark lime': 55,
#  'dark olive': 56,
#  'dull white': 57,
#  'shiny gray': 58,
#  'dotted orange': 59,
#  'clear olive': 60,
#  'drab bronze': 61,
#  'drab chartreuse': 62,
#  'faded cyan': 63,
#  'plaid fuchsia': 64,
#  'light gold': 65,
#  'pale bronze': 66,
#  'shiny coral': 67,
#  'vibrant green': 68,
#  'vibrant violet': 69,
#  'muted fuchsia': 70,
#  'bright olive': 71,
#  'mirrored maroon': 72,
#  'pale salmon': 73,
#  'faded brown': 74,
#  'dark lavender': 75,
#  'plaid coral': 76,
#  'drab black': 77,
#  'shiny black': 78,
#  'muted plum': 79,
#  'shiny lavender': 80,
#  'mirrored blue': 81,
#  'dotted aqua': 82,
#  'light lavender': 83,
#  'bright orange': 84,
#  'muted tomato': 85,
#  'dim indigo': 86,
#  'faded turquoise': 87,
#  'wavy teal': 88,
#  'dotted bronze': 89,
#  'posh purple': 90,
#  'dull violet': 91,
#  'drab indigo': 92,
#  'mirrored crimson': 93,
#  'mirrored tan': 94,
#  'wavy fuchsia': 95,
#  'striped yellow': 96,
#  'striped white': 97,
#  'light turquoise': 98,
#  'clear blue': 99,
#  'faded blue': 100,
#  'dim aqua': 101,
#  'shiny magenta': 102,
#  'wavy maroon': 103,
#  'plaid teal': 104,
#  'bright tomato': 105,
#  'mirrored lavender': 106,
#  'vibrant purple': 107,
#  'posh aqua': 108,
#  'faded fuchsia': 109,
#  'dim silver': 110,
#  'bright brown': 111,
#  'dim olive': 112,
#  'striped teal': 113,
#  'posh plum': 114,
#  'faded teal': 115,
#  'striped indigo': 116,
#  'drab blue': 117,
#  'light olive': 118,
#  'vibrant red': 119,
#  'faded salmon': 120,
#  'shiny brown': 121,
#  'posh olive': 122,
#  'clear green': 123,
#  'mirrored violet': 124,
#  'light brown': 125,
#  'plaid blue': 126,
#  'dim green': 127,
#  'mirrored plum': 128,
#  'dotted turquoise': 129,
#  'dull salmon': 130,
#  'wavy plum': 131,
#  'bright blue': 132,
#  'posh tomato': 133,
#  'dotted lavender': 134,
#  'posh magenta': 135,
#  'faded beige': 136,
#  'vibrant plum': 137,
#  'pale green': 138,
#  'dull fuchsia': 139,
#  'light plum': 140,
#  'dotted olive': 141,
#  'striped gold': 142,
#  'bright violet': 143,
#  'dim yellow': 144,
#  'bright indigo': 145,
#  'plaid lime': 146,
#  'striped aqua': 147,
#  'dull maroon': 148,
#  'muted tan': 149,
#  'plaid tan': 150,
#  'dull beige': 151,
#  'posh cyan': 152,
#  'drab red': 153,
#  'drab gray': 154,
#  'muted red': 155,
#  'drab green': 156,
#  'dim gray': 157,
#  'dark white': 158,
#  'posh black': 159,
#  'dim turquoise': 160,
#  'drab lavender': 161,
#  'striped crimson': 162,
#  'vibrant olive': 163,
#  'dim maroon': 164,
#  'muted lime': 165,
#  'drab purple': 166,
#  'muted beige': 167,
#  'dotted green': 168,
#  'bright black': 169,
#  'wavy yellow': 170,
#  'faded yellow': 171,
#  'dim purple': 172,
#  'bright chartreuse': 173,
#  'vibrant maroon': 174,
#  'pale fuchsia': 175,
#  'dotted teal': 176,
#  'dull lime': 177,
#  'bright salmon': 178,
#  'bright magenta': 179,
#  'striped red': 180,
#  'pale teal': 181,
#  'clear cyan': 182,
#  'muted gray': 183,
#  'bright gold': 184,
#  'clear red': 185,
#  'striped purple': 186,
#  'plaid violet': 187,
#  'shiny crimson': 188,
#  'posh gold': 189,
#  'dim crimson': 190,
#  'posh red': 191,
#  'drab turquoise': 192,
#  'vibrant cyan': 193,
#  'light bronze': 194,
#  'dotted cyan': 195,
#  'drab fuchsia': 196,
#  'clear maroon': 197,
#  'dim salmon': 198,
#  'wavy aqua': 199,
#  'pale beige': 200,
#  'dark maroon': 201,
#  'light aqua': 202,
#  'dim tan': 203,
#  'vibrant brown': 204,
#  'light magenta': 205,
#  'clear turquoise': 206,
#  'dull crimson': 207,
#  'dull orange': 208,
#  'wavy black': 209,
#  'plaid olive': 210,
#  'plaid indigo': 211,
#  'dim brown': 212,
#  'muted indigo': 213,
#  'dull plum': 214,
#  'vibrant tan': 215,
#  'plaid tomato': 216,
#  'shiny white': 217,
#  'plaid red': 218,
#  'drab orange': 219,
#  'striped green': 220,
#  'shiny indigo': 221,
#  'drab yellow': 222,
#  'faded magenta': 223,
#  'muted yellow': 224,
#  'posh brown': 225,
#  'pale tomato': 226,
#  'dark aqua': 227,
#  'muted blue': 228,
#  'light silver': 229,
#  'muted coral': 230,
#  'muted green': 231,
#  'muted brown': 232,
#  'dim violet': 233,
#  'clear fuchsia': 234,
#  'muted violet': 235,
#  'posh violet': 236,
#  'dark violet': 237,
#  'dotted fuchsia': 238,
#  'vibrant indigo': 239,
#  'vibrant gray': 240,
#  'dotted plum': 241,
#  'vibrant magenta': 242,
#  'drab maroon': 243,
#  'dotted gold': 244,
#  'striped cyan': 245,
#  'pale silver': 246,
#  'drab coral': 247,
#  'vibrant chartreuse': 248,
#  'pale maroon': 249,
#  'wavy blue': 250,
#  'mirrored green': 251,
#  'shiny purple': 252,
#  'dim white': 253,
#  'posh maroon': 254,
#  'posh chartreuse': 255,
#  'dim orange': 256,
#  'clear gray': 257,
#  'dull purple': 258,
#  'muted olive': 259,
#  'pale lavender': 260,
#  'shiny blue': 261,
#  'plaid salmon': 262,
#  'mirrored silver': 263,
#  'light blue': 264,
#  'light orange': 265,
#  'faded tomato': 266,
#  'shiny lime': 267,
#  'shiny fuchsia': 268,
#  'light indigo': 269,
#  'faded aqua': 270,
#  'posh blue': 271,
#  'dotted crimson': 272,
#  'striped salmon': 273,
#  'clear brown': 274,
#  'clear orange': 275,
#  'shiny teal': 276,
#  'dim bronze': 277,
#  'shiny silver': 278,
#  'dim tomato': 279,
#  'vibrant white': 280,
#  'dark blue': 281,
#  'plaid gray': 282,
#  'mirrored indigo': 283,
#  'mirrored cyan': 284,
#  'dotted red': 285,
#  'clear crimson': 286,
#  'mirrored brown': 287,
#  'pale gray': 288,
#  'bright gray': 289,
#  'dotted purple': 290,
#  'dotted indigo': 291,
#  'wavy orange': 292,
#  'dark plum': 293,
#  'vibrant yellow': 294,
#  'vibrant bronze': 295,
#  'striped silver': 296,
#  'dull yellow': 297,
#  'wavy turquoise': 298,
#  'drab salmon': 299,
#  'posh green': 300,
#  'muted gold': 301,
#  'mirrored aqua': 302,
#  'wavy tan': 303,
#  'mirrored magenta': 304,
#  'mirrored lime': 305,
#  'dark crimson': 306,
#  'striped blue': 307,
#  'wavy chartreuse': 308,
#  'clear magenta': 309,
#  'dim beige': 310,
#  'striped tan': 311,
#  'faded green': 312,
#  'drab teal': 313,
#  'posh lavender': 314,
#  'bright tan': 315,
#  'light red': 316,
#  'light white': 317,
#  'faded gray': 318,
#  'light gray': 319,
#  'light teal': 320,
#  'muted teal': 321,
#  'dull chartreuse': 322,
#  'vibrant salmon': 323,
#  'mirrored gold': 324,
#  'dark yellow': 325,
#  'plaid crimson': 326,
#  'shiny gold': 327,
#  'pale olive': 328,
#  'dotted magenta': 329,
#  'striped violet': 330,
#  'faded lime': 331,
#  'muted magenta': 332,
#  'dim lime': 333,
#  'plaid cyan': 334,
#  'dotted maroon': 335,
#  'striped gray': 336,
#  'light violet': 337,
#  'vibrant gold': 338,
#  'vibrant lavender': 339,
#  'clear yellow': 340,
#  'muted black': 341,
#  'pale brown': 342,
#  'plaid purple': 343,
#  'vibrant fuchsia': 344,
#  'light purple': 345,
#  'mirrored white': 346,
#  'dull silver': 347,
#  'dark magenta': 348,
#  'faded red': 349,
#  'mirrored beige': 350,
#  'faded coral': 351,
#  'shiny cyan': 352,
#  'posh gray': 353,
#  'dim cyan': 354,
#  'dotted tomato': 355,
#  'dark teal': 356,
#  'muted cyan': 357,
#  'dotted yellow': 358,
#  'dark cyan': 359,
#  'dark bronze': 360,
#  'drab cyan': 361,
#  'drab white': 362,
#  'bright cyan': 363,
#  'dull lavender': 364,
#  'shiny olive': 365,
#  'posh fuchsia': 366,
#  'plaid aqua': 367,
#  'shiny plum': 368,
#  'striped chartreuse': 369,
#  'pale red': 370,
#  'plaid maroon': 371,
#  'shiny beige': 372,
#  'plaid silver': 373,
#  'light cyan': 374,
#  'faded silver': 375,
#  'light green': 376,
#  'faded maroon': 377,
#  'posh tan': 378,
#  'muted silver': 379,
#  'mirrored turquoise': 380,
#  'clear coral': 381,
#  'clear teal': 382,
#  'muted lavender': 383,
#  'shiny tan': 384,
#  'dark salmon': 385,
#  'plaid orange': 386,
#  'clear black': 387,
#  'bright red': 388,
#  'striped tomato': 389,
#  'light maroon': 390,
#  'dark indigo': 391,
#  'faded violet': 392,
#  'clear violet': 393,
#  'dotted violet': 394,
#  'dotted brown': 395,
#  'wavy gray': 396,
#  'faded black': 397,
#  'shiny bronze': 398,
#  'faded purple': 399,
#  'dim plum': 400,
#  'plaid turquoise': 401,
#  'clear tomato': 402,
#  'bright green': 403,
#  'drab tomato': 404,
#  'clear indigo': 405,
#  'bright crimson': 406,
#  'dark coral': 407,
#  'light salmon': 408,
#  'dark purple': 409,
#  'dotted beige': 410,
#  'muted crimson': 411,
#  'wavy gold': 412,
#  'faded crimson': 413,
#  'shiny chartreuse': 414,
#  'dull magenta': 415,
#  'shiny turquoise': 416,
#  'drab aqua': 417,
#  'dim teal': 418,
#  'light yellow': 419,
#  'striped olive': 420,
#  'dark green': 421,
#  'light black': 422,
#  'dull brown': 423,
#  'shiny green': 424,
#  'shiny salmon': 425,
#  'clear aqua': 426,
#  'wavy beige': 427,
#  'plaid yellow': 428,
#  'clear beige': 429,
#  'clear lime': 430,
#  'vibrant beige': 431,
#  'bright yellow': 432,
#  'plaid plum': 433,
#  'plaid green': 434,
#  'dull tan': 435,
#  'clear bronze': 436,
#  'vibrant crimson': 437,
#  'vibrant orange': 438,
#  'plaid beige': 439,
#  'dull indigo': 440,
#  'muted white': 441,
#  'shiny aqua': 442,
#  'bright fuchsia': 443,
#  'dull bronze': 444,
#  'muted maroon': 445,
#  'striped fuchsia': 446,
#  'shiny tomato': 447,
#  'wavy lime': 448,
#  'wavy tomato': 449,
#  'striped coral': 450,
#  'clear silver': 451,
#  'vibrant tomato': 452,
#  'faded gold': 453,
#  'striped bronze': 454,
#  'dotted chartreuse': 455,
#  'vibrant coral': 456,
#  'faded lavender': 457,
#  'dull turquoise': 458,
#  'shiny yellow': 459,
#  'plaid lavender': 460,
#  'mirrored fuchsia': 461,
#  'wavy white': 462,
#  'clear purple': 463,
#  'dark chartreuse': 464,
#  'wavy purple': 465,
#  'bright lavender': 466,
#  'shiny red': 467,
#  'pale aqua': 468,
#  'wavy brown': 469,
#  'clear chartreuse': 470,
#  'mirrored chartreuse': 471,
#  'pale turquoise': 472,
#  'dotted blue': 473,
#  'bright plum': 474,
#  'pale black': 475,
#  'dotted coral': 476,
#  'plaid magenta': 477,
#  'striped lavender': 478,
#  'striped magenta': 479,
#  'pale tan': 480,
#  'light crimson': 481,
#  'pale coral': 482,
#  'vibrant blue': 483,
#  'dark tan': 484,
#  'drab olive': 485,
#  'wavy violet': 486,
#  'plaid gold': 487,
#  'plaid bronze': 488,
#  'wavy cyan': 489,
#  'vibrant black': 490,
#  'faded white': 491,
#  'mirrored orange': 492,
#  'dark gold': 493,
#  'muted turquoise': 494,
#  'dull blue': 495,
#  'light tomato': 496,
#  'striped turquoise': 497,
#  'wavy magenta': 498,
#  'posh bronze': 499,
#  'drab silver': 500,
#  'bright maroon': 501,
#  'dull red': 502,
#  'pale gold': 503,
#  'wavy red': 504,
#  'mirrored gray': 505,
#  'drab plum': 506,
#  'mirrored teal': 507,
#  'dotted tan': 508,
#  'dark gray': 509,
#  'pale indigo': 510,
#  'bright white': 511,
#  'clear white': 512,
#  'faded tan': 513,
#  'striped lime': 514,
#  'dim blue': 515,
#  'mirrored tomato': 516,
#  'wavy coral': 517,
#  'dark silver': 518,
#  'dim fuchsia': 519,
#  'light lime': 520,
#  'mirrored red': 521,
#  'light chartreuse': 522,
#  'dull teal': 523,
#  'dull aqua': 524,
#  'pale white': 525,
#  'wavy salmon': 526,
#  'faded chartreuse': 527,
#  'posh beige': 528,
#  'posh crimson': 529,
#  'shiny orange': 530,
#  'wavy lavender': 531,
#  'vibrant aqua': 532,
#  'dim magenta': 533,
#  'wavy olive': 534,
#  'dull green': 535,
#  'dotted gray': 536,
#  'mirrored salmon': 537,
#  'faded orange': 538,
#  'plaid black': 539,
#  'dull coral': 540,
#  'pale chartreuse': 541,
#  'mirrored black': 542,
#  'drab crimson': 543,
#  'muted orange': 544,
#  'pale orange': 545,
#  'clear salmon': 546,
#  'dull tomato': 547,
#  'pale crimson': 548,
#  'dotted white': 549,
#  'posh teal': 550,
#  'dim coral': 551,
#  'bright aqua': 552,
#  'dark beige': 553,
#  'bright teal': 554,
#  'dotted silver': 555,
#  'striped maroon': 556,
#  'pale magenta': 557,
#  'shiny maroon': 558,
#  'dark black': 559,
#  'posh white': 560,
#  'muted aqua': 561,
#  'pale cyan': 562,
#  'plaid white': 563,
#  'bright beige': 564,
#  'dotted black': 565,
#  'bright purple': 566,
#  'faded plum': 567,
#  'dull gold': 568,
#  'dark tomato': 569,
#  'pale yellow': 570,
#  'vibrant turquoise': 571,
#  'mirrored coral': 572,
#  'muted salmon': 573,
#  'pale plum': 574,
#  'clear gold': 575,
#  'muted chartreuse': 576,
#  'light coral': 577,
#  'faded indigo': 578,
#  'bright turquoise': 579,
#  'clear plum': 580,
#  'plaid chartreuse': 581,
#  'faded bronze': 582,
#  'bright lime': 583,
#  'drab violet': 584,
#  'dull olive': 585,
#  'wavy indigo': 586,
#  'posh indigo': 587,
#  'dull cyan': 588,
#  'plaid brown': 589,
#  'mirrored purple': 590,
#  'striped plum': 591,
#  'dim lavender': 592,
#  'dim chartreuse': 593}

# %%
# inner bag colors as indices
idxs_cols_inner=[]
for curcols in colors_inner:
    curidxs=[converter[c] for c in curcols]
    idxs_cols_inner.append(curidxs)
idxs_cols_inner[:3]
# Out:
# [[575], [453, 367, 387], [198, 120, 160]]

# %% [markdown]
# create color transition matrix: outer -> inner
# * Rows: outer color, Columns: inner color
# * one row stands for: all the possible inner colors that can be contained in that specific outer color
# * To check whether a specific inner color can be contained in an outer bag: check the corresponding column if it contains a nonzero element

# %%
numcolors=len(colors_outer)
numcolors
# Out:
# 594

# %%
Tmat=np.zeros((numcolors,numcolors)) # transition matrix

# %%
for idx in range(len(colors_inner)):
    Tmat[idx,idxs_cols_inner[idx]]=counts_inner[idx]

# %% [markdown]
# shiny gold bag
# * sum up in which bags it can be contained after 1,2,3,... iterations (iteration here means: 1,2,3 bags mamoushka style packed into each other)

# %%
goldidx=converter["shiny gold"]
goldidx
# Out:
# 327

# %%
# number of bags that contain directly a shiny gold bag: (for exploration)
len(np.nonzero(Tmat[:,goldidx])[0])
# Out:
# 9

# %%
# number of bags that contain a shiny gold bag after 0,1,2,3,... iterations
Tn=np.identity(numcolors)
idxs_outer=np.array([])
for idx in range(numcolors):
    Tn=Tmat.dot(Tn)
    idxs_outer=np.concatenate((idxs_outer,(np.nonzero(Tn[:,goldidx])[0])))
    print(idx,",  ",np.sum(Tn[:,goldidx]))
    if np.sum(Tn[:,goldidx])==0:
        break # we'll never get a shiny gold bag further inside
# Out:
# 0 ,   29.0
# 1 ,   363.0
# 2 ,   2607.0
# 3 ,   15247.0
# 4 ,   69932.0
# 5 ,   303486.0
# 6 ,   858136.0
# 7 ,   1729542.0
# 8 ,   2492780.0
# 9 ,   5314344.0
# 10 ,   4776696.0
# 11 ,   5867472.0
# 12 ,   12665088.0
# 13 ,   14307840.0
# 14 ,   33868800.0
# 15 ,   19353600.0
# 16 ,   0.0

# %%
# total number of different outer bags
len(np.unique(idxs_outer))
# Out:
# 370

# %% [markdown]
# #### exploration: time profiling

# %%
# %load_ext line_profiler

# %%
def test_fct():
    # the idx finding function copied. uses global vars
    Tn=np.identity(numcolors)
    idxs_outer=np.array([])

    for idx in range(numcolors):
        Tn=Tmat.dot(Tn)
        idxs_outer=np.concatenate((idxs_outer,(np.nonzero(Tn[:,goldidx])[0])))
        print(idx,",  ",np.sum(Tn[:,goldidx]))
        if np.sum(Tn[:,goldidx])==0:
            break # we'll never get a shiny gold bag further inside

# %%
# %lprun -f test_fct test_fct()
# Out:
# 0 ,   29.0
# 1 ,   363.0
# 2 ,   2607.0
# 3 ,   15247.0
# 4 ,   69932.0
# 5 ,   303486.0
# 6 ,   858136.0
# 7 ,   1729542.0
# 8 ,   2492780.0
# 9 ,   5314344.0
# 10 ,   4776696.0
# 11 ,   5867472.0
# 12 ,   12665088.0
# 13 ,   14307840.0
# 14 ,   33868800.0
# 15 ,   19353600.0
# 16 ,   0.0

# %% [markdown]
# #### exploration: regex with groups

# %%
line=lines[1]
outer, inner=line.split("contain")
print(inner,"\n")

pattern=r"(?P<count>\d) (?P<color>\w+ \w+) bags?"

# return all detected groups as list of tuples
x=re.findall(pattern,inner)
print(x,"\n")

# return all detected match objects and access the strings in a loop
iterable=re.finditer(pattern, inner)
for m in iterable:
    print(m.group(0)) # full match
    print(m.group("color"), m.group("count"))
    print(m.groupdict(),"\n") # alternative
# Out:
#  3 faded gold bags, 3 plaid aqua bags, 2 clear black bags.
#
# [('3', 'faded gold'), ('3', 'plaid aqua'), ('2', 'clear black')]
#
# 3 faded gold bags
# faded gold 3
# {'count': '3', 'color': 'faded gold'}
#
# 3 plaid aqua bags
# plaid aqua 3
# {'count': '3', 'color': 'plaid aqua'}
#
# 2 clear black bags
# clear black 2
# {'count': '2', 'color': 'clear black'}

# %% [markdown]
# #### Part B
# now the shiny gold bag is outside

# %%
# all bags that are contained in a shiny gold bag
Tn=np.identity(numcolors)

counter=0 # count number of bags inside the golden one

for idx in range(numcolors): # after 0,1,2,... packing iterations
    Tn=Tmat.dot(Tn)
    curcount=np.sum(Tn[goldidx,:])
    print(idx,",  ",curcount)
    counter+=curcount
    if np.max(Tn)==0:
        break # we'll never get a shiny gold bag further inside since whole matrix is 0
# Out:
# 0 ,   7.0
# 1 ,   70.0
# 2 ,   701.0
# 3 ,   2245.0
# 4 ,   1574.0
# 5 ,   7850.0
# 6 ,   17100.0
# 7 ,   0.0
# 8 ,   0.0
# 9 ,   0.0
# 10 ,   0.0
# 11 ,   0.0
# 12 ,   0.0
# 13 ,   0.0
# 14 ,   0.0
# 15 ,   0.0
# 16 ,   0.0
# 17 ,   0.0
# 18 ,   0.0
# 19 ,   0.0
# 20 ,   0.0
# 21 ,   0.0
# 22 ,   0.0
# 23 ,   0.0
# 24 ,   0.0

# %%
# total nr of bags in side the shiny golden one
counter
# Out:
# 29547.0
